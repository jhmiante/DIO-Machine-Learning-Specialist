# %% [markdown]
# # 1º Código Python para ML

# %% [markdown]
# OBJETIVO: Gerar um

# %%
import matplotlib
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %% [markdown]
# Gerando uma amostra de 200 dados com ruido de 30

# %%
x, y = make_regression(n_samples=200, n_features=1, noise=30, random_state=42)

# %%
plt.scatter(x, y)
plt.show()
